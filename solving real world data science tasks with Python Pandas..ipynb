# %% [markdown]
# ### Solving real world data science tasks with Python Pandas!, sales in usa market per months

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#import csv file from location , taken sales of months of april
df = pd.read_csv('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\sales_april_2019.csv')
#concate or mearge csv of different months
all_months_data = pd.DataFrame()

#using os functin and by putting os. listdirection , we can mearge the csv !!


files =[file for file in os.listdir('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]
for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df = pd.read_csv('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\sales_april_2019.csv')
#concate or mearge csv of different months

files =[file for file in os.listdir('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data/'+file)
    all_months_data  = pd.concat([all_months_data, df]) # look above the csv how its mearging 
    
all_months_data.head(5)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_months_data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
df = pd.read_csv('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\sales_april_2019.csv')
#concate or mearge csv of different months

files =[file for file in os.listdir('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('file_100\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data/'+file)
    all_months_data  = pd.concat([all_months_data, df]) # concat is used to combine all the month given in the given data
    
all_months_data.to_csv('all_data.csv', index =False)

# %% [markdown]
# ### Read in updated dataframe

# %%
all_data = pd.read_csv('all_data.csv') #all data is csv file given  there, now from order date we can get month details by using string
all_data['month'] = all_data['Order Date'].str[0:2]
all_data.head(2)
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   176558  USB-C Charging Cable                2      11.95  04/19/19 08:46
# 1      NaN                   NaN              NaN        NaN             NaN
#
#                Purchase Address month
# 0  917 1st St, Dallas, TX 75001    04
# 1                           NaN   NaN

# %% [markdown]
# ### dropping nan value

# %%
#there is a nan value in given data , from that we have drop allthe nan value to get the answer
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df
#dropna is used to drop all nan function ,( how = all ) to all nan function should be dropped
all_data =all_data.dropna(how = 'all')
all_data.head(2)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address month
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215    04

# %% [markdown]
# ### find or and delete it

# %% [markdown]
# ###  convert column to the correct type

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered']) # Make int
all_data['Price Each'] =  pd.to_numeric(all_data['Price Each']) # make float
all_data.head(2)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
#
#        Order Date                   Purchase Address  month          City
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001      4   Dallas (TX)
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215      4   Boston (MA)

# %%
#error is coming as there is Or value coming in month columns ,so we have to remove or by using below function
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head(2)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address month
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215    04

# %% [markdown]
# # Augment data with additional columns

# %% [markdown]
# ### task 2: Add Month Columns

# %%
#addimg new columns im given  data , by using order date
all_data['month'] = all_data['Order Date'].str[0:2]
all_data['month'] =all_data['month'].astype('int32') #need to find astype method is used for
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Task 3 : Add a sales columns

# %%
#adding saales colums  by multiply Qunt order , price each..

all_data['sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City   sales
# 0        Dallas (TX)   23.90
# 2        Boston (MA)   99.99
# 3   Los Angeles (CA)  600.00
# 4   Los Angeles (CA)   11.99
# ...

# %% [markdown]
# ### Task 4 : Add a city columns

# %%
#lets use apply method:(why we using apply method , need to know more about lambda)
all_data['City'] = all_data['Purchase Address'].apply(lambda x : x.split(',')[1])

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month          City
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4        Dallas
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4        Boston
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   Los Angeles
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   Los Angeles
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   Los Angeles

# %%
#lets use apply method

def get_city(address):
    return address.split(',')[1]
all_data['City'] = all_data['Purchase Address'].apply(lambda x : get_city(x))

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month          City
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4        Dallas
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4        Boston
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   Los Angeles
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   Los Angeles
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   Los Angeles

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]
all_data['City'] = all_data['Purchase Address'].apply(lambda x : get_city(x)+' '+ get_state(x))

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#               City
# 0        Dallas TX
# 2        Boston MA
# 3   Los Angeles CA
# 4   Los Angeles CA
# 5   Los Angeles CA

# %%
#using another format f" so that we can directly use without adding + value
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]
all_data['City'] = all_data['Purchase Address'].apply(lambda x : f"{get_city(x)} ({get_state(x)})")

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City
# 0        Dallas (TX)
# 2        Boston (MA)
# 3   Los Angeles (CA)
# 4   Los Angeles (CA)
# 5   Los Angeles (CA)

# %%
all_data['City']
# Out:
# 0                 Dallas (TX)
# 2                 Boston (MA)
# 3            Los Angeles (CA)
# 4            Los Angeles (CA)
# 5            Los Angeles (CA)
#                  ...
# 186845       Los Angeles (CA)
# 186846     San Francisco (CA)
# 186847     San Francisco (CA)
# 186848     San Francisco (CA)
# 186849     San Francisco (CA)
# Name: City, Length: 185950, dtype: object

# %% [markdown]
# ### What was the best month for sales? How much was earned that monthly?

# %%
sales_by_months = all_data.groupby('month').sum()

# %%
sales_by_months.describe()
# Out:
#        Quantity Ordered    Price Each         sales
# count         12.000000  1.200000e+01  1.200000e+01
# mean       17423.250000  2.857428e+06  2.874336e+06
# std         4848.761681  7.889619e+05  7.931995e+05
# min        10903.000000  1.811768e+06  1.822257e+06
# 25%        13448.750000  2.219980e+06  2.233857e+06
# 50%        16538.500000  2.711874e+06  2.727438e+06
# 75%        19988.000000  3.227368e+06  3.247370e+06
# max        28114.000000  4.588415e+06  4.613443e+06

# %%
sales_by_months.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 1 to 12
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Quantity Ordered  12 non-null     int64
#  1   Price Each        12 non-null     float64
#  2   sales             12 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 384.0 bytes

# %% [markdown]
# ### plotting the sales per month on graph

# %%
plt.figure(figsize =(12,6))
months = range(1,13)
plt.bar(months , sales_by_months['sales'], color = 'green')
plt.plot(months , sales_by_months['sales'], color = 'red')
plt.xticks(months)
plt.ylabel('sales in USD($)in million')
plt.xlabel('months')
plt.show()

# %% [markdown]
# #### What city had a highest number of sales?

# %%
result = all_data.groupby('City').sum()
result
# Out:
#                      Quantity Ordered  Price Each   month       sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48

# %%
plt.figure(figsize =(12,6))
cities = [city for city, df in all_data.groupby('City')]
plt.bar(cities , result['sales'], color = 'blue')
plt.plot(cities , result['sales'], color = 'red')

plt.xticks(cities , rotation ='vertical', size= 8)
plt.ylabel('sales in USD($)in million')
plt.xlabel('City NAme')
plt.show()

# %% [markdown]
# ### Question 3: What time should we display advertisements to minimize likelihood of customer's buying product?
# ### time 52:19 (solving real world data science tasks with Python Pandas)

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   sales
# 0        Dallas (TX)   23.90
# 2        Boston (MA)   99.99
# 3   Los Angeles (CA)  600.00
# ...

# %% [markdown]
# #### adding HOur column in data

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour  # adding hour simply by datetime function
all_data['Minute'] = all_data['Order Date'].dt.minute  #adding minute  in data extract from P.Address
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   sales  Hour  Minute
# 0        Dallas (TX)   23.90     8      46
# 2        Boston (MA)   99.99    22      30
# ...

# %%
plt.figure(figsize=(12,6))
hours = [ hour for hour, df in all_data.groupby('Hour')]
plt.xticks(hours)
plt.grid()
plt.ylabel('Number of Order')
plt.xlabel('Hour')
plt.plot(hours, all_data.groupby(['Hour']).count(), color ='red');

# %% [markdown]
# ### What products are most often sold together ?

# %%
all_data['Product'].unique()
# Out:
# array(['USB-C Charging Cable', 'Bose SoundSport Headphones',
#        'Google Phone', 'Wired Headphones', 'Macbook Pro Laptop',
#        'Lightning Charging Cable', '27in 4K Gaming Monitor',
#        'AA Batteries (4-pack)', 'Apple Airpods Headphones',
#        'AAA Batteries (4-pack)', 'iPhone', 'Flatscreen TV',
#        '27in FHD Monitor', '20in Monitor', 'LG Dryer', 'ThinkPad Laptop',
#        'Vareebadd Phone', 'LG Washing Machine', '34in Ultrawide Monitor'],
#       dtype=object)

# %%
df = all_data[all_data['Order ID'].duplicated(keep = False)]

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186792   259303       AA Batteries (4-pack)                 1        3.84
# 186803   259314            Wired Headphones                 1       11.99
# 186804   259314      AAA Batteries (4-pack)                 2        2.99
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                       Purchase Address  month  \
# ...

# %%
df = all_data[all_data['Order ID'].duplicated(keep = False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))

#dropping the duplicate ,so that there will be only one order history
df = df[['Order ID', 'Grouped']].drop_duplicates()
df.head()
# Out:
# C:\Users\91808\AppData\Local\Temp/ipykernel_9916/2052734915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %% [markdown]
# #Referanced :https://stackoverflow.com/question/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
#
# from itertools import combinations
# from collections import counter
#
# count = counter()
#
# for row in df['Grouped']:
#     row_list = row_split(',')
#     count.update(counter(combinations(row_list, 2)))
#
# print(count)
# # solve it later when i gain knowledge about  import errror

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   sales  Hour  Minute
# 0        Dallas (TX)   23.90     8      46
# 2        Boston (MA)   99.99    22      30
# ...

# %% [markdown]
# ### Question 5: What product sold the most? why dpo you thinks it sold the most?

# %%
product_group = all_data.groupby('Product')
print(product_group)

# %%
plt.figure(figsize=(12,6))
product_group = all_data.groupby('Product')

quantity_ordered = product_group.sum()['Quantity Ordered']

products = [product for product , df in product_group]
plt.grid()
plt.bar(products ,quantity_ordered ,color ='yellow')
plt.plot(products ,quantity_ordered, color ='red')
plt.yticks(rotation = '45', size =10)
plt.xlabel('Product', color= 'red', size =20)
plt.ylabel('Quantity Ordered', color= 'green',size = 20)
plt.xticks(rotation = 'vertical',size =12);

# %%
prices = all_data.groupby('Product').mean()['Price Each']
print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
plt.figure(figsize=(12,6))
prices = all_data.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products ,quantity_ordered, color ='green')
ax2.plot(products, prices ,'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color ='g');

ax2.set_ylabel('Price ($)', color = 'b');
ax1.set_xticklabels( products, rotation = 'vertical', size =12);
# Out:
# C:\Users\91808\AppData\Local\Temp/ipykernel_9916/566744392.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels( products, rotation = 'vertical', size =12);
